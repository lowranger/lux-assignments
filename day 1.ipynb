# %%
import pandas as pd

df= pd.read_csv(r"simplelinearregression.csv")
df.head(20)
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
#import libraries
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
x= df[['Age']]
y= df['Premium']

# %%
lin =   LinearRegression()
lin.fit(x,y)
# Out:
# LinearRegression()

# %%
print("Intercept:", lin.intercept_)
print("Slope:", lin.coef_[0])
# Out:
# Intercept: -10114.726027397246
# Slope: 1172.9452054794515

# %%
df['Predicted'] = lin.predict(x)

plt.scatter(df['Age'], df['Premium'], label='Actual', color='blue')
plt.plot(df['Age'], df['Predicted'], label='Regressiopn Line', color='red')
plt.title('Simple Linear Regression')
plt.xlabel('Age')
plt.ylabel('Premium')
plt.legend()
plt.grid()
plt.show()
